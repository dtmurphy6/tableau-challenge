# %%
import pandas as pd

# %%
jun21 = pd.read_csv("Data/JC-202106-citibike-tripdata.csv")
jun21["month"] = "June"
jun21["year"] = "2021"
jun21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  7830EBE775F2EE25  classic_bike  2021-06-21 07:38:42  2021-06-21 10:49:25
# 1  629A3BFD50BF8392   docked_bike  2021-06-12 10:25:01  2021-06-12 10:35:11
# 2  CF02EC434989A99D   docked_bike  2021-06-07 14:52:05  2021-06-07 14:58:25
# 3  E1BB8FED29AA5BA1   docked_bike  2021-06-07 08:29:19  2021-06-07 08:34:17
# 4  787C59EE76D96BCA   docked_bike  2021-06-18 14:16:27  2021-06-18 14:26:26
#
#       start_station_name start_station_id  \
# 0            Dixon Mills            JC076
# 1            Dixon Mills            JC076
# 2  11 St & Washington St            HB502
# 3   8 St & Washington St            HB603
# 4  11 St & Washington St            HB502
#
#                            end_station_name end_station_id  start_lat  \
# 0                                       NaN            NaN  40.721630
# 1                            Journal Square          JC103  40.721630
# ...

# %%
jun22 = pd.read_csv("Data/JC-202206-citibike-tripdata.csv")
jun22["month"] = "June"
jun22["year"] = "2022"
jun22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16  2022-06-30 19:27:13
# 1  BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44  2022-06-02 15:08:33
# 2  DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34  2022-06-05 14:27:12
# 3  A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12  2022-06-01 19:05:58
# 4  A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53  2022-06-14 22:49:39
#
#        start_station_name start_station_id  end_station_name end_station_id  \
# 0  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 1  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 2  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 3  Clinton St & Newark St            HB409    Pershing Field          JC024
# 4             Oakland Ave            JC022    Pershing Field          JC024
#
# ...

# %%
jul21 = pd.read_csv("Data/JC-202107-citibike-tripdata.csv")
jul21["month"] = "July"
jul21["year"] = "2021"
jul21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C9446233AFAB8896   classic_bike  2021-07-15 19:27:25  2021-07-15 19:27:35
# 1  0C3D69370BE39992  electric_bike  2021-07-22 06:41:54  2021-07-22 06:42:03
# 2  3B0390B706281176   classic_bike  2021-07-19 06:36:13  2021-07-19 06:38:18
# 3  9AFBC07247ABE507   classic_bike  2021-07-08 06:33:45  2021-07-08 06:35:53
# 4  ADB073F7FFC372D3   classic_bike  2021-07-21 07:33:49  2021-07-21 08:00:14
#
#                   start_station_name start_station_id  \
# 0                     Journal Square            JC103
# 1                     Journal Square            JC103
# 2                    Brunswick & 6th            JC081
# 3                    Brunswick & 6th            JC081
# 4  14 St Ferry - 14 St & Shipyard Ln            HB202
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0              Journal Square          JC103  40.733670 -74.062500  40.733670
# ...

# %%
jul22 = pd.read_csv("Data/JC-202207-citbike-tripdata.csv")
jul22["month"] = "July"
jul22["year"] = "2022"
jul22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  89CDCE3224502904   classic_bike  2022-07-21 18:19:45  2022-07-21 18:28:21
# 1  3E6E50F51BD4CBD9  electric_bike  2022-07-21 17:50:57  2022-07-21 17:59:17
# 2  8A9058FAA9115562  electric_bike  2022-07-23 11:51:55  2022-07-23 11:59:16
# 3  C566A187663748AE   classic_bike  2022-07-30 20:34:40  2022-07-30 20:48:40
# 4  7E754D57276BE57E   classic_bike  2022-07-14 18:42:34  2022-07-14 18:49:45
#
#    start_station_name start_station_id       end_station_name end_station_id  \
# 0  Marshall St & 2 St            HB408   8 St & Washington St          HB603
# 1  Marshall St & 2 St            HB408  11 St & Washington St          HB502
# 2  Marshall St & 2 St            HB408            Oakland Ave          JC022
# 3  Marshall St & 2 St            HB408  Bloomfield St & 15 St          HB203
# 4  Marshall St & 2 St            HB408      Clinton St & 7 St          HB303
#
# ...

# %%
aug21 = pd.read_csv("Data/JC-202108-citibike-tripdata.csv")
aug21["month"] = "August"
aug21["year"] = "2021"
aug21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  A113F664678F00EC   classic_bike  2021-08-31 08:42:09  2021-08-31 08:50:01
# 1  181C24F4DAD629B4   classic_bike  2021-08-14 18:16:31  2021-08-14 18:46:40
# 2  89F02E7FE759B7C6  electric_bike  2021-08-22 04:19:40  2021-08-22 04:41:52
# 3  664FA523777D686C   classic_bike  2021-08-19 08:05:53  2021-08-19 08:11:44
# 4  4B1FE4E68C7E9721   classic_bike  2021-08-11 14:54:27  2021-08-11 15:16:43
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                 Communipaw & Berry Lane            JC084
# 2                             Astor Place            JC077
# 3                             Astor Place            JC077
# 4       14 St Ferry - 14 St & Shipyard Ln            HB202
#
#           end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
aug22 = pd.read_csv("Data/JC-202208-citibike-tripdata.csv")
aug22["month"] = "August"
aug22["year"] = "2022"
aug22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  D68047AAA9A72501   classic_bike  2022-08-12 18:14:45  2022-08-12 18:21:23
# 1  E5B82A9F588A7650   classic_bike  2022-08-19 01:04:39  2022-08-19 01:14:10
# 2  13D19CCBCC9D7B76   classic_bike  2022-08-19 18:13:45  2022-08-19 19:32:47
# 3  AA0DBFF220DA98F6   classic_bike  2022-08-21 13:43:05  2022-08-21 13:53:13
# 4  8F11D340492FCD32  electric_bike  2022-08-04 22:02:12  2022-08-04 22:21:31
#
#                              start_station_name start_station_id  \
# 0                                Columbus Drive            JC014
# 1  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
# 2  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
# 3                                Columbus Drive            JC014
# 4  South Waterfront Walkway - Sinatra Dr & 1 St            HB103
#
#         end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
df = [jun21, jun22, jul21, jul22, aug21, aug22]
data = pd.concat(df)
data.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  7830EBE775F2EE25  classic_bike  2021-06-21 07:38:42  2021-06-21 10:49:25
# 1  629A3BFD50BF8392   docked_bike  2021-06-12 10:25:01  2021-06-12 10:35:11
# 2  CF02EC434989A99D   docked_bike  2021-06-07 14:52:05  2021-06-07 14:58:25
# 3  E1BB8FED29AA5BA1   docked_bike  2021-06-07 08:29:19  2021-06-07 08:34:17
# 4  787C59EE76D96BCA   docked_bike  2021-06-18 14:16:27  2021-06-18 14:26:26
#
#       start_station_name start_station_id  \
# 0            Dixon Mills            JC076
# 1            Dixon Mills            JC076
# 2  11 St & Washington St            HB502
# 3   8 St & Washington St            HB603
# 4  11 St & Washington St            HB502
#
#                            end_station_name end_station_id  start_lat  \
# 0                                       NaN            NaN  40.721630
# 1                            Journal Square          JC103  40.721630
# ...

# %%
data.to_csv("Data/JC-Summer-2021-2022-citibike-tripdata.csv")
